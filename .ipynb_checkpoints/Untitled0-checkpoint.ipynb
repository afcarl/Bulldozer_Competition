# %%
import pandas as pd
import pylab as pl
import numpy as np
from scipy.stats.kde import gaussian_kde
from scipy.stats import norm as stats_norm
from scipy import stats
import statsmodels.api as sm
import statsmodels.stats.api as sms

import pdb

# from sklearn.linear_model import LinearRegression, Lasso, Ridge, ElasticNet
# from sklearn.linear_model import LassoCV, RidgeCV
# from sklearn.cross_validation import train_test_split
# from sklearn.preprocessing import scale

from dateutil.parser import parse
import datetime

# first we ingest the data from the source on the web
# this contains a reduced version of the data set from Lending Club

appdx = pd.read_csv('data/machine_appendix.csv')
machine_data  = pd.read_csv('data/data.csv', parse_dates=['saledate'], date_parser=lambda d: parse(d))

machine_data['Sale_Year']  = machine_data["saledate"].apply(lambda x: x.year)
machine_data['Sale_Month'] = machine_data["saledate"].apply(lambda x: x.month)
machine_data['Age']        = machine_data["Sale_Year"] - machine_data["YearMade"]

# %%
data = machine_data[["SalePrice", "MachineID", "ModelID", "YearMade", "Sale_Year", "Sale_Month", "Age"]]

wrong_age = data[data['Age'] < 0]
print wrong_age
#pdb.set_trace()

for index, machine_data in wrong_age.iterrows():
    found_row = appdx[appdx['MachineID'] == machine_data['MachineID']] #use with matrices appdx.ix[appdx['MachineID'] == machine]
    print found_row['MachineID'], found_row['MfgYear']
#    print data.loc[[index]]
#    data.loc[[index]]['YearMade'] = found_row["MfgYear"]
 #   print data.loc[[index]]
  #  K


    #print wrong_age["MachineID"]

# t = [data.ix[data['Age'] < 0]
# df[df['Correlation'] >= 0]


#.fromtimestamp(int("1284101485")).strftime('%Y-%m-%d %H:%M:%S'))


# unique_models = appdx["ModelID"].unique()
# unique_models





# def search_dataframe(_id, _df, _column):
#     return _df.ix[_df[_column] == _id]

# t = search_dataframe(3538, appdx, "MachineID")
# print t.head()



# model
# for model_id in unique_models:
#     tractor_collection = appdx.ix[appdx['ModelID'] == model_id]
    
#     model_build_years = tractor_collection["MfgYear"].unique()

# # build_years   = unique_models["MfgYear"].unique()

# print build_years
# Out:
#         SalePrice  MachineID  ModelID  YearMade  Sale_Year  Sale_Month  Age
# 22206       27000    1424836     3247      1997       1996          12   -1
# 65360       29000    1189094     3538      2000       1999          10   -1
# 129054      60000    1482307    28842      2006       2005           2   -1
# 141271      72000    1104056     4753      1998       1997           5   -1
# 167403       8500    1481256    14755      2008       2001          10   -7
# 170645      12000    1151751     4988      2008       1996           2  -12
# 185451      22500    1106818     8954      2006       1996           7  -10
# 194288      27000    1361981      257      2008       1997          12  -11
# 201309     100000    1241578      457      2002       1995           8   -7
# 236703      35000      40066     4125      2012       2010           5   -2
# 238474      43750     255273     1614      2009       2008           8   -1
# ...

# %%
# model = appdx.ix[appdx['ModelID'] == 3538]unique_models

# %%
model.head(50)
# Out:
# /Users/zipfianstudent/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /Users/zipfianstudent/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
# /Users/zipfianstudent/anaconda/lib/python2.7/site-packages/pandas/core/config.py:570: DeprecationWarning: height has been deprecated.
#
#   warnings.warn(d.msg, DeprecationWarning)
#      MachineID  ModelID fiModelDesc fiBaseModel fiSecondaryDesc fiModelSeries  \
# 1          434     3538        416C         416               C           NaN
# 2          534     3538        416C         416               C           NaN
# 3          718     3538        416C         416               C           NaN
# 5         2055     3538        416C         416               C           NaN
# ...

# %%
for unique in unique_models:
    
    1139592,29500,1006823,3538,121,3,1998,5126,Medium,2/23/2006 0:00,416C,416,C,,,,Backhoe Loader - 14.0 to 15.0 Ft Standard Digging Depth,Kentucky,BL,Backhoe Loaders,Four Wheel Drive,EROPS,None or Unspecified,Reversible,No,Standard,Standard,None or Unspecified,,,,,,,,,,,,,,,,,,,,,,,,,
